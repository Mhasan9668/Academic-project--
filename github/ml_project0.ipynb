# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score

# %%
df = pd.read_csv('data/canada_per_capita_income.csv')

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     47 non-null     int64
#  1   per capita income (US$)  47 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 884.0 bytes

# %%
df.isnull().sum()
# Out:
# year                       0
# per capita income (US$)    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['year', 'per capita income (US$)'], dtype='object')

# %%
x=df.drop(columns=['per capita income (US$)'])
y=df['per capita income (US$)']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_test
# Out:
#     year
# 27  1997
# 41  2011
# 3   1973
# 18  1988
# 2   1972
# 34  2004
# 15  1985
# 44  2014
# 7   1977
# 13  1983

# %%
y_test
# Out:
# 27    17310.757750
# 41    42334.711210
# 3      4804.463248
# 18    15080.283450
# 2      4251.175484
# 34    25719.147150
# 15    11018.955850
# 44    41039.893600
# 7      7100.126170
# 13    10416.536590
# Name: per capita income (US$), dtype: float64

# %%
x_train
# Out:
#     year
# 29  1999
# 40  2010
# 32  2002
# 0   1970
# 22  1992
# 31  2001
# 12  1982
# 33  2003
# 11  1981
# 35  2005
# 21  1991
# 6   1976
# 8   1978
# 23  1993
# 39  2009
# 45  2015
# 17  1987
# 43  2013
# 4   1974
# 19  1989
# 10  1980
# 16  1986
# 20  1990
# 37  2007
# 25  1995
# 28  1998
# 9   1979
# 24  1994
# 1   1971
# 14  1984
# 30  2000
# 46  2016
# 5   1975
# 26  1996
# 38  2008
# 42  2012
# 36  2006

# %%
y_train
# Out:
# 29    17581.024140
# 40    38420.522890
# 32    19232.175560
# 0      3399.299037
# 22    16412.083090
# 31    18601.397240
# 12     9619.438377
# 33    22739.426280
# 11     9434.390652
# 35    29198.055690
# 21    17266.097690
# 6      7062.131392
# 8      7247.967035
# 23    15875.586730
# 39    32755.176820
# 45    35175.188980
# 17    12974.806620
# 43    42676.468370
# 4      5576.514583
# 19    16426.725480
# 10     8355.968120
# 16    11482.891530
# 20    16838.673200
# 37    36144.481220
# 25    16369.317250
# 28    16622.671870
# 9      7602.912681
# 24    15755.820270
# 1      3768.297935
# 14    10790.328720
# 30    18987.382410
# 46    34229.193630
# 5      5998.144346
# 26    16699.826680
# 38    37446.486090
# 42    42665.255970
# 36    32738.262900
# Name: per capita income (US$), dtype: float64

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# -1607588.391725496
# [815.96026523]

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([21884.25794152, 33307.70165476,  2301.21157597, 14540.61555444,
#         1485.25131074, 27595.97979814, 12092.73475874, 35755.58245045,
#         5565.05263689, 10460.81422828])

# %%
print('MSE:',mean_squared_error(y_test,y_pred))
print('RMSE:',np.sqrt(mean_squared_error(y_test,y_pred)))
print('R2 Score',r2_score(y_test,y_pred))
# Out:
# MSE: 15156950.993604619
# RMSE: 3893.19290475114
# R2 Score 0.9148350994593601

# %%
plt.scatter(x_test,y_test)
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.plot(x_test,y_pred,color='red')
plt.title('YearsExperience vs Salary')
plt.show()

# %%
plt.scatter(x_train,y_train)
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.plot(x_test,y_pred,color='red')
plt.title('YearsExperience vs Salary')
plt.show()
